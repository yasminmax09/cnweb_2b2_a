# %% [markdown]
# <a href="https://colab.research.google.com/github/yasminmax09/cnweb_2b2_a/blob/main/cinematica-aula0330.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formula da Velocidade

# %%
def calculaVelMedia(deltaS, deltaT):
  velMedia = (deltaS/deltaT)
  return velMedia

# %% [markdown]
# # Teste Serviço Nuvem: Velocidade Média

# %%
print("Vm=", calculaVelMedia(30, 15))
# Out:
# Vm= 2.0

# %% [markdown]
# # Fórmula da aceleração

# %%
def calculaAceleracaomedia(deltaV, deltaT):
  aceleracaoMedia = (deltaV/deltaT)
  return aceleracaoMedia

# %% [markdown]
# # Teste de Função: Aceleração Média

# %%
print("Am", calculaAceleracaomedia(30,15))
# Out:
# Am 2.0

# %% [markdown]
# # Fórmulas do Movimento Uniforme (MU)

# %%
def calculaPosicao(posicao_inicial, velocidade, tempo):
  posicao_final = posicao_inicial + (velocidade * tempo)
  return posicao_final

# %% [markdown]
# # Teste de função: Posição Final

# %%
print("Movimento Uniforme",calculaPosicao(15,2,5) )
# Out:
# Movimento Uniforme 25

# %% [markdown]
# # Função horária do deslocamento

# %%
def calculaDesloc(inicialS, deltaT, v):
  d = inicialS + (v*deltaT)
  return d

# %% [markdown]
# # Testes de Função : Horária de Deslocamento

# %%
print("Deslocamento= ",calculaDesloc(0, 15, 30))
# Out:
# Deslocamento=  450

# %% [markdown]
# # Fórmulas do Movimento Uniformemente Variado (MUV)

# %% [markdown]
# # Função horária da velocidade

# %% [markdown]
# # Função horária da posição

# %% [markdown]
# # Equação de Torricelli

# %%
import math

def calTorricelli(vZero, acel, des):
  t=2*acel*des
  v=vZero+t
  res = math.sqrt(v)
  return res

# %% [markdown]
# # Testes do Torricelli

# %%
print("Calculo de Torricelli:", calTorricelli(0,1,8))
# Out:
# Calculo de Torricelli: 4.0

# %% [markdown]
# # Fórmula do movimento vertical
